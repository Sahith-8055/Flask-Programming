# %%
from pycaret.datasets import get_data
data = get_data('insurance')
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from pycaret.regression import *

# %%
s = setup(data, target='charges', session_id=123)
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
# </style>
# <table id="T_6686e2e2_a27d_11ea_9904_204747ba98ad" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Description</th>
#         <th class="col_heading level0 col1" >Value</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow0_col0" class="data row0 col0" >session_id</td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow0_col1" class="data row0 col1" >123</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow1_col0" class="data row1 col0" >Transform Target </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow1_col1" class="data row1 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow2_col0" class="data row2 col0" >Transform Target Method</td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow2_col1" class="data row2 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow3_col0" class="data row3 col0" >Original Data</td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow4_col0" class="data row4 col0" >Missing Values </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow4_col1" class="data row4 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow5_col0" class="data row5 col0" >Numeric Features </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow5_col1" class="data row5 col1" >2</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow6_col0" class="data row6 col0" >Categorical Features </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow6_col1" class="data row6 col1" >4</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow7_col0" class="data row7 col0" >Ordinal Features </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow7_col1" class="data row7 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow8_col0" class="data row8 col0" >High Cardinality Features </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow8_col1" class="data row8 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow9_col0" class="data row9 col0" >High Cardinality Method </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow9_col1" class="data row9 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow10_col0" class="data row10 col0" >Sampled Data</td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow10_col1" class="data row10 col1" >(1338, 7)</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row11" class="row_heading level0 row11" >11</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow11_col1" class="data row11 col1" >(936, 14)</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row12" class="row_heading level0 row12" >12</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow12_col1" class="data row12 col1" >(402, 14)</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row13" class="row_heading level0 row13" >13</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow13_col0" class="data row13 col0" >Numeric Imputer </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow13_col1" class="data row13 col1" >mean</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row14" class="row_heading level0 row14" >14</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow14_col0" class="data row14 col0" >Categorical Imputer </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow14_col1" class="data row14 col1" >constant</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row15" class="row_heading level0 row15" >15</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow15_col0" class="data row15 col0" >Normalize </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow15_col1" class="data row15 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row16" class="row_heading level0 row16" >16</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow16_col0" class="data row16 col0" >Normalize Method </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow16_col1" class="data row16 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row17" class="row_heading level0 row17" >17</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow17_col0" class="data row17 col0" >Transformation </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow17_col1" class="data row17 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row18" class="row_heading level0 row18" >18</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow18_col0" class="data row18 col0" >Transformation Method </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow18_col1" class="data row18 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row19" class="row_heading level0 row19" >19</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow19_col0" class="data row19 col0" >PCA </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow19_col1" class="data row19 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row20" class="row_heading level0 row20" >20</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow20_col0" class="data row20 col0" >PCA Method </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow20_col1" class="data row20 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row21" class="row_heading level0 row21" >21</th>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow21_col0" class="data row21 col0" >PCA Components </td>
#         <td id="T_6686e2e2_a27d_11ea_9904_204747ba98adrow21_col1" class="data row21 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_6686e2e2_a27d_11ea_9904_204747ba98adlevel0_row22" class="row_heading level0 row22" >22</th>

# %%
lr = create_model('lr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     4165.9659  3.330203e+07  5770.7909  0.8011  0.4683  0.4153
# 1     4503.7366  4.374648e+07  6614.1122  0.7456  0.5633  0.4217
# 2     3880.5528  3.179514e+07  5638.7179  0.5974  0.7645  0.4396
# 3     3747.6457  2.680530e+07  5177.3833  0.7762  0.5015  0.5175
# 4     4471.0419  4.341053e+07  6588.6670  0.6771  0.5224  0.3767
# 5     4182.7551  3.616633e+07  6013.8450  0.7674  0.7416  0.4320
# 6     4081.1022  3.919259e+07  6260.3984  0.7333  0.6434  0.4241
# 7     4928.1534  4.641504e+07  6812.8581  0.7448  0.5887  0.4137
# 8     4609.3147  4.037035e+07  6353.7670  0.7392  0.5686  0.5111
# 9     4665.8647  4.259679e+07  6526.6220  0.7256  0.8131  0.4802
# Mean  4323.6133  3.838006e+07  6175.7162  0.7308  0.6175  0.4432
# SD     353.5472  5.908389e+06   490.4977  0.0543  0.1126  0.0431

# %%
plot_model(lr)

# %%
s2 = setup(data, target = 'charges', session_id = 123,
           normalize = True,
           polynomial_features = True, trigonometry_features = True, feature_interaction=True, 
           bin_numeric_features= ['age', 'bmi'])
# Out:
#
# Setup Succesfully Completed!
# <style  type="text/css" >
#     #T_b32b3ae8_a27d_11ea_a191_204747ba98adrow15_col1 {
#             background-color:  lightgreen;
#         }    #T_b32b3ae8_a27d_11ea_a191_204747ba98adrow25_col1 {
#             background-color:  lightgreen;
#         }    #T_b32b3ae8_a27d_11ea_a191_204747ba98adrow32_col1 {
#             background-color:  lightgreen;
#         }    #T_b32b3ae8_a27d_11ea_a191_204747ba98adrow34_col1 {
#             background-color:  lightgreen;
#         }    #T_b32b3ae8_a27d_11ea_a191_204747ba98adrow39_col1 {
#             background-color:  lightgreen;
#         }</style>
# <table id="T_b32b3ae8_a27d_11ea_a191_204747ba98ad" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Description</th>
#         <th class="col_heading level0 col1" >Value</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row0" class="row_heading level0 row0" >0</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow0_col0" class="data row0 col0" >session_id</td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow0_col1" class="data row0 col1" >123</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row1" class="row_heading level0 row1" >1</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow1_col0" class="data row1 col0" >Transform Target </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow1_col1" class="data row1 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row2" class="row_heading level0 row2" >2</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow2_col0" class="data row2 col0" >Transform Target Method</td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow2_col1" class="data row2 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row3" class="row_heading level0 row3" >3</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow3_col0" class="data row3 col0" >Original Data</td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow3_col1" class="data row3 col1" >(1338, 7)</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row4" class="row_heading level0 row4" >4</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow4_col0" class="data row4 col0" >Missing Values </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow4_col1" class="data row4 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row5" class="row_heading level0 row5" >5</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow5_col0" class="data row5 col0" >Numeric Features </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow5_col1" class="data row5 col1" >2</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row6" class="row_heading level0 row6" >6</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow6_col0" class="data row6 col0" >Categorical Features </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow6_col1" class="data row6 col1" >4</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row7" class="row_heading level0 row7" >7</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow7_col0" class="data row7 col0" >Ordinal Features </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow7_col1" class="data row7 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row8" class="row_heading level0 row8" >8</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow8_col0" class="data row8 col0" >High Cardinality Features </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow8_col1" class="data row8 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row9" class="row_heading level0 row9" >9</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow9_col0" class="data row9 col0" >High Cardinality Method </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow9_col1" class="data row9 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row10" class="row_heading level0 row10" >10</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow10_col0" class="data row10 col0" >Sampled Data</td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow10_col1" class="data row10 col1" >(1338, 7)</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row11" class="row_heading level0 row11" >11</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow11_col0" class="data row11 col0" >Transformed Train Set</td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow11_col1" class="data row11 col1" >(936, 62)</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row12" class="row_heading level0 row12" >12</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow12_col0" class="data row12 col0" >Transformed Test Set</td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow12_col1" class="data row12 col1" >(402, 62)</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row13" class="row_heading level0 row13" >13</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow13_col0" class="data row13 col0" >Numeric Imputer </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow13_col1" class="data row13 col1" >mean</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row14" class="row_heading level0 row14" >14</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow14_col0" class="data row14 col0" >Categorical Imputer </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow14_col1" class="data row14 col1" >constant</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row15" class="row_heading level0 row15" >15</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow15_col0" class="data row15 col0" >Normalize </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow15_col1" class="data row15 col1" >True</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row16" class="row_heading level0 row16" >16</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow16_col0" class="data row16 col0" >Normalize Method </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow16_col1" class="data row16 col1" >zscore</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row17" class="row_heading level0 row17" >17</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow17_col0" class="data row17 col0" >Transformation </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow17_col1" class="data row17 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row18" class="row_heading level0 row18" >18</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow18_col0" class="data row18 col0" >Transformation Method </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow18_col1" class="data row18 col1" >None</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row19" class="row_heading level0 row19" >19</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow19_col0" class="data row19 col0" >PCA </td>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow19_col1" class="data row19 col1" >False</td>
#     </tr>    <tr>
#         <th id="T_b32b3ae8_a27d_11ea_a191_204747ba98adlevel0_row20" class="row_heading level0 row20" >20</th>
#         <td id="T_b32b3ae8_a27d_11ea_a191_204747ba98adrow20_col0" class="data row20 col0" >PCA Method </td>
#         <td id="T_b32b3ae8_a27d_11ea_a19

# %%
s2[0].columns
# Out:
# Index(['age_Power2', 'bmi_Power2', 'sex_female', 'children_0', 'children_1',
#        'children_2', 'children_3', 'children_4', 'children_5', 'smoker_yes',
#        'region_northeast', 'region_northwest', 'region_southeast',
#        'region_southwest', 'age_0.0', 'age_1.0', 'age_10.0', 'age_11.0',
#        'age_2.0', 'age_3.0', 'age_4.0', 'age_5.0', 'age_6.0', 'age_7.0',
#        'age_8.0', 'age_9.0', 'bmi_0.0', 'bmi_1.0', 'bmi_10.0', 'bmi_11.0',
#        'bmi_2.0', 'bmi_3.0', 'bmi_4.0', 'bmi_5.0', 'bmi_6.0', 'bmi_7.0',
#        'bmi_8.0', 'bmi_9.0', 'children_2_multiply_age_Power2',
#        'bmi_Power2_multiply_age_Power2', 'children_1_multiply_smoker_yes',
#        'smoker_yes_multiply_children_2', 'smoker_yes_multiply_bmi_5.0',
#        'bmi_7.0_multiply_smoker_yes', 'region_southeast_multiply_age_Power2',
#        'smoker_yes_multiply_children_0', 'sex_female_multiply_age_Power2',
#        'smoker_yes_multiply_bmi_Power2', 'children_0_multiply_age_Power2',
#        'bmi_Power2_multiply_smoker_yes',
#        'region_southeast_multiply_smoker_yes',
#        'age_Power2_multiply_smoker_yes', 'sex_female_multiply_bmi_Power2',
#        'region_southeast_multiply_bmi_Power2',
#        'children_1_multiply_age_Power2', 'sex_female_multiply_smoker_yes',
#        'region_southwest_multiply_smoker_yes',
#        'children_0_multiply_bmi_Power2', 'bmi_6.0_multiply_smoker_yes',
#        'smoker_yes_multiply_age_Power2', 'smoker_yes_multiply_sex_female',
#        'children_0_multiply_smoker_yes'],
#       dtype='object')

# %%
lr = create_model('lr')
# Out:
#             MAE           MSE       RMSE      R2   RMSLE    MAPE
# 0     2421.9303  1.723250e+07  4151.2044  0.8971  0.3840  0.2817
# 1     3438.5898  3.433564e+07  5859.6624  0.8004  0.4464  0.3374
# 2     2885.7380  2.167287e+07  4655.4135  0.7256  0.5810  0.3939
# 3     2866.4424  2.019161e+07  4493.5073  0.8314  0.4671  0.3628
# 4     3155.4276  2.884575e+07  5370.8235  0.7855  0.5138  0.2995
# 5     3139.4247  2.170956e+07  4659.3517  0.8603  0.3949  0.3060
# 6     2740.8440  2.310004e+07  4806.2501  0.8428  0.4086  0.3351
# 7     3069.5508  2.736680e+07  5231.3290  0.8495  0.4531  0.2918
# 8     2834.8307  2.085590e+07  4566.8265  0.8653  0.3856  0.3268
# 9     3041.8892  2.646975e+07  5144.8761  0.8295  0.4690  0.3299
# Mean  2959.4668  2.417804e+07  4893.9245  0.8287  0.4504  0.3265
# SD     261.8437  4.786279e+06   477.0178  0.0458  0.0593  0.0323

# %%
plot_model(lr)

# %%
save_model(lr, 'deployment_28042020')
# Out:
# Transformation Pipeline and Model Succesfully Saved

# %%
deployment_28042020 = load_model('deployment_28042020')
# Out:
# Transformation Pipeline and Model Sucessfully Loaded

# %%
deployment_28042020
# Out:
# [Pipeline(memory=None,
#           steps=[('dtypes',
#                   DataTypes_Auto_infer(categorical_features=[],
#                                        display_types=True, features_todrop=[],
#                                        ml_usecase='regression',
#                                        numerical_features=[], target='charges',
#                                        time_features=[])),
#                  ('imputer',
#                   Simple_Imputer(categorical_strategy='not_available',
#                                  numeric_strategy='mean',
#                                  target_variable=None)),
#                  ('new_levels1',
#                   New_Catagorical_Levels...
#                  ('dummy', Dummify(target='charges')),
#                  ('fix_perfect', Remove_100(target='charges')),
#                  ('clean_names', Clean_Colum_Names()),
#                  ('feature_select', Empty()), ('fix_multi', Empty()),
#                  ('dfs',
#                   DFS_Classic(interactions=['multiply'], ml_usecase='regression',
#                               random_state=123, subclass='binary',
#                               target='charges',
#                               top_features_to_pick_percentage=None)),
#                  ('pca', Empty())],
#           verbose=False),
#  LinearRegression(copy_X=True, fit_intercept=True, n_jobs=None, normalize=False),
#  None]

# %%
import requests
url = 'https://pycaret-insurance.herokuapp.com/predict_api'
pred = requests.post(url,json={'age':55, 'sex':'male', 'bmi':59, 'children':1, 'smoker':'male', 'region':'northwest'})
print(pred.json())
# Out:
# 75714.0
